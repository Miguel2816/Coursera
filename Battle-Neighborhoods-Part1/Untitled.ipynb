# %%
import pandas as pd
from folium import plugins
import requests

# %%
CLIENT_ID = 'FHRGXUUQOWVRRBRFMUOVMI3EPOA54GTYVQJGYWEFKMFYDIDG'
CLIENT_SECRET = '3YTTEIB4LUSPZL4DYXX0FREKHIYOFOWMS5SXTRHAGFBOPTR1'

request_parameters = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": '20180605',
    "section": "food",
    "near": "Krakow",
    "radius": 4000,
    "limit": 100}

# %%
data = requests.get("https://api.foursquare.com/v2/venues/explore", params=request_parameters)

# %%
d = data.json()["response"]
d.keys()
# Out:
# dict_keys(['suggestedFilters', 'geocode', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
d["headerLocationGranularity"], d["headerLocation"], d["headerFullLocation"]
# Out:
# ('city', 'Krakow', 'Krakow')

# %%
d["suggestedBounds"], d["totalResults"]
# Out:
# ({'ne': {'lat': 50.07844066002748, 'lng': 19.96527575117025},
#   'sw': {'lat': 50.043369873332026, 'lng': 19.901070740353166}},
#  203)

# %%
d
# Out:
# {'suggestedFilters': {'header': 'Tap to show:',
#   'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#  'geocode': {'what': '',
#   'where': 'krakow',
#   'center': {'lat': 50.06143, 'lng': 19.93658},
#   'displayString': 'Krakow, Poland',
#   'cc': 'PL',
#   'geometry': {'bounds': {'ne': {'lat': 50.125746929273035,
#      'lng': 20.217017998898445},
#     'sw': {'lat': 49.96750603553661, 'lng': 19.793890515115354}}},
#   'slug': 'krakow-poland',
#   'longId': '72057594041022738'},
#  'headerLocation': 'Krakow',
#  'headerFullLocation': 'Krakow',
#  'headerLocationGranularity': 'city',
#  'query': 'food',
#  'totalResults': 203,
#  'suggestedBounds': {'ne': {'lat': 50.07844066002748,
#    'lng': 19.96527575117025},
#   'sw': {'lat': 50.043369873332026, 'lng': 19.901070740353166}},
#  'groups': [{'type': 'Recommended Places',
#    'name': 'recommended',
#    'items': [{'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '597cc55b6dcf041c42573b04',
#       'name': 'Pizzatopia',
#       'location': {'address': 'Szewska 22',
#        'lat': 50.062943238240265,
#        'lng': 19.933833687142826,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.062943238240265,
#          'lng': 19.933833687142826}],
#        'postalCode': '31-009',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Lesser Poland',
#        'country': 'Polska',
#        'formattedAddress': ['Szewska 22', '31-009 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1ca941735',
#         'name': 'Pizza Place',
#         'pluralName': 'Pizza Places',
#         'shortName': 'Pizza',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-597cc55b6dcf041c42573b04-0'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4dc6ad07887717c88041ae1e',
#       'name': 'Farina',
#       'location': {'address': 'Św. Marka 16',
#        'lat': 50.0640334464296,
#        'lng': 19.939355768346665,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.0640334464296,
#          'lng': 19.939355768346665}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Św. Marka 16', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1ce941735',
#         'name': 'Seafood Restaurant',
#         'pluralName': 'Seafood Restaurants',
#         'shortName': 'Seafood',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4dc6ad07887717c88041ae1e-1'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '53e678c5498e35f10c8bcbfa',
#       'name': 'Bianca Pasta & Wine',
#       'location': {'address': 'Plac Mariacki 2',
#        'lat': 50.06189929786526,
#        'lng': 19.939740570081543,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06189929786526,
#          'lng': 19.939740570081543}],
#        'postalCode': '31-042',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Plac Mariacki 2', '31-042 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-53e678c5498e35f10c8bcbfa-2'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4e6f50cb483bd41a3db4dfa4',
#       'name': 'MoaBurger',
#       'location': {'address': 'Mikołajska 3',
#        'lat': 50.061306,
#        'lng': 19.94131,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.061306,
#          'lng': 19.94131}],
#        'postalCode': '31-027',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Mikołajska 3', '31-027 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16c941735',
#         'name': 'Burger Joint',
#         'pluralName': 'Burger Joints',
#         'shortName': 'Burgers',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4e6f50cb483bd41a3db4dfa4-3'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '53a1380f498e903f74523f65',
#       'name': 'Massolit Bakery & Cafe',
#       'location': {'address': 'Smoleńsk 17',
#        'lat': 50.05897520106757,
#        'lng': 19.93035131472727,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05897520106757,
#          'lng': 19.93035131472727}],
#        'postalCode': '31-108',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Małopolska',
#        'country': 'Polska',
#        'formattedAddress': ['Smoleńsk 17', '31-108 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16a941735',
#         'name': 'Bakery',
#         'pluralName': 'Bakeries',
#         'shortName': 'Bakery',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-53a1380f498e903f74523f65-4'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '56377311498ea3a0befc336c',
#       'name': 'Bonerowska Gourmet Steak & Fish',
#       'location': {'address': 'Rynek Główny 42',
#        'crossStreet': 'Św. Jana 1',
#        'lat': 50.062246209045256,
#        'lng': 19.937986638524116,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.062246209045256,
#          'lng': 19.937986638524116}],
#        'postalCode': '31-013',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Rynek Główny 42 (Św. Jana 1)',
#         '31-013 Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1cc941735',
#         'name': 'Steakhouse',
#         'pluralName': 'Steakhouses',
#         'shortName': 'Steakhouse',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-56377311498ea3a0befc336c-5'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b813ff5f964a520259c30e3',
#       'name': 'Café Camelot',
#       'location': {'address': 'Świętego Tomasza 17',
#        'lat': 50.06309816140206,
#        'lng': 19.939010481384162,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06309816140206,
#          'lng': 19.939010481384162}],
#        'postalCode': '31-022',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Świętego Tomasza 17', '31-022 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4b813ff5f964a520259c30e3-6'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4facdb7fe5e83b277dae66de',
#       'name': 'Charlotte - Chleb i Wino',
#       'location': {'address': 'Plac Szczepański 2',
#        'lat': 50.06345546470003,
#        'lng': 19.935068575643378,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06345546470003,
#          'lng': 19.935068575643378}],
#        'postalCode': '31-011',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Plac Szczepański 2', '31-011 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4facdb7fe5e83b277dae66de-7'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4c00dc18ceabb7138aef8752',
#       'name': 'Bunkier Café',
#       'location': {'address': 'Plac Szczepański 3a',
#        'crossStreet': 'Planty',
#        'lat': 50.063576699392655,
#        'lng': 19.93408036969639,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.063576699392655,
#          'lng': 19.93408036969639}],
#        'postalCode': '31-011',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Plac Szczepański 3a (Planty)',
#         '31-011 Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4c00dc18ceabb7138aef8752-8'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '592005654940bc3f72327973',
#       'name': 'La Petite France',
#       'location': {'address': 'Szpitalna 20',
#        'lat': 50.062824667841234,
#        'lng': 19.941311250095055,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.062824667841234,
#          'lng': 19.941311250095055}],
#        'postalCode': '31-024',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Lesser Poland',
#        'country': 'Polska',
#        'formattedAddress': ['Szpitalna 20', '31-024 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d10c941735',
#         'name': 'French Restaurant',
#         'pluralName': 'French Restaurants',
#         'shortName': 'French',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-592005654940bc3f72327973-9'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4be1a1a885670f474eae2bd7',
#       'name': 'Morskie Oko',
#       'location': {'address': 'Plac Szczepański 8',
#        'lat': 50.06381357541125,
#        'lng': 19.935761796827308,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06381357541125,
#          'lng': 19.935761796827308}],
#        'postalCode': '31-011',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Plac Szczepański 8', '31-011 Kraków', 'Polska']},
#       'categories': [{'id': '52e81612bcbc57f1066b7a04',
#         'name': 'Polish Restaurant',
#         'pluralName': 'Polish Restaurants',
#         'shortName': 'Polish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4be1a1a885670f474eae2bd7-10'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '58e61a587b88a736f5704c95',
#       'name': 'Café Lisboa',
#       'location': {'address': 'Dolnych Młynów 3/4',
#        'lat': 50.063796,
#        'lng': 19.927934,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.063796,
#          'lng': 19.927934}],
#        'postalCode': '31-124',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Dolnych Młynów 3/4', '31-124 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '535460389'}},
#      'referralId': 'e-3-58e61a587b88a736f5704c95-11'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '58d17d6103e29a046afb1621',
#       'name': 'Big hat of coffee',
#       'location': {'address': 'Zwierzyniecka 15',
#        'lat': 50.057933938967736,
#        'lng': 19.931333617174598,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.057933938967736,
#          'lng': 19.931333617174598}],
#        'postalCode': '31-103',
#        'cc': 'PL',
#        'neighborhood': 'Старый Город',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Zwierzyniecka 15', '31-103 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-58d17d6103e29a046afb1621-12'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4ee89103775b712266299aec',
#       'name': 'Milkbar Tomasza',
#       'location': {'address': 'Św. Tomasza 24',
#        'lat': 50.0624160479784,
#        'lng': 19.941412074127463,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.0624160479784,
#          'lng': 19.941412074127463}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Św. Tomasza 24', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d147941735',
#         'name': 'Diner',
#         'pluralName': 'Diners',
#         'shortName': 'Diner',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4ee89103775b712266299aec-13'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '514a32cf582f79f38dc2a565',
#       'name': 'Pod Norenami',
#       'location': {'address': 'Krupnicza 6',
#        'lat': 50.0635011801023,
#        'lng': 19.931314734000782,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.0635011801023,
#          'lng': 19.931314734000782}],
#        'postalCode': '31-216',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Krupnicza 6', '31-216 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1d3941735',
#         'name': 'Vegetarian / Vegan Restaurant',
#         'pluralName': 'Vegetarian / Vegan Restaurants',
#         'shortName': 'Vegetarian / Vegan',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-514a32cf582f79f38dc2a565-14'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5659cff4498e8316341276ba',
#       'name': 'Vegab',
#       'location': {'address': 'Starowiślna 6',
#        'lat': 50.05843279002551,
#        'lng': 19.943310465562334,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05843279002551,
#          'lng': 19.943310465562334}],
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Starowiślna 6', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1d3941735',
#         'name': 'Vegetarian / Vegan Restaurant',
#         'pluralName': 'Vegetarian / Vegan Restaurants',
#         'shortName': 'Vegetarian / Vegan',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5659cff4498e8316341276ba-15'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4cc884e241e75481702a5784',
#       'name': 'Pimiento Argentino Grill',
#       'location': {'address': 'Stolarska 13',
#        'lat': 50.05977979058244,
#        'lng': 19.938507822604333,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05977979058244,
#          'lng': 19.938507822604333}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Stolarska 13', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d107941735',
#         'name': 'Argentinian Restaurant',
#         'pluralName': 'Argentinian Restaurants',
#         'shortName': 'Argentinian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4cc884e241e75481702a5784-16'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4bbf956d920eb7136697172c',
#       'name': 'Chimera',
#       'location': {'address': 'Świętej Anny 3',
#        'lat': 50.06182551124878,
#        'lng': 19.934927963784688,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06182551124878,
#          'lng': 19.934927963784688}],
#        'postalCode': '31-008',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Świętej Anny 3', '31-008 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1bd941735',
#         'name': 'Salad Place',
#         'pluralName': 'Salad Places',
#         'shortName': 'Salad',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4bbf956d920eb7136697172c-17'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '55832870498ea0faf6e920e8',
#       'name': 'Meat & Go',
#       'location': {'address': 'Dolnych Młynów 10',
#        'lat': 50.06462371759251,
#        'lng': 19.925853654875343,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06462371759251,
#          'lng': 19.925853654875343}],
#        'postalCode': '31-121',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Dolnych Młynów 10', '31-121 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1c5941735',
#         'name': 'Sandwich Place',
#         'pluralName': 'Sandwich Places',
#         'shortName': 'Sandwiches',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-55832870498ea0faf6e920e8-18'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4d8dec3cd265236aaf07fd16',
#       'name': 'Karma',
#       'location': {'address': 'Krupnicza 12/3',
#        'lat': 50.063395,
#        'lng': 19.930564,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.063395,
#          'lng': 19.930564}],
#        'postalCode': '31-123',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Krupnicza 12/3', '31-123 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4d8dec3cd265236aaf07fd16-19'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '566ab4fb498eba26bfeb137f',
#       'name': 'Fitagain Café',
#       'location': {'address': 'Szczepańska 7',
#        'lat': 50.06307307560663,
#        'lng': 19.93621509305541,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06307307560663,
#          'lng': 19.93621509305541}],
#        'postalCode': '31-011',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Szczepańska 7', '31-011 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-566ab4fb498eba26bfeb137f-20'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4bf2548524f19c74448bf983',
#       'name': 'Kiełbaski z Niebieskiej Nyski',
#       'location': {'address': 'Grzegórzecka (pod Halą Targową)',
#        'lat': 50.058780192669126,
#        'lng': 19.948757943183864,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.058780192669126,
#          'lng': 19.948757943183864}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Grzegórzecka (pod Halą Targową)',
#         'Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1cb941735',
#         'name': 'Food Truck',
#         'pluralName': 'Food Trucks',
#         'shortName': 'Food Truck',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4bf2548524f19c74448bf983-21'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '51cf0eb9498ede5bd396324d',
#       'name': 'Meho Cafe',
#       'location': {'address': 'Krupnicza 26',
#        'lat': 50.06342195864872,
#        'lng': 19.92829769559223,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06342195864872,
#          'lng': 19.92829769559223}],
#        'postalCode': '31-123',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Krupnicza 26', '31-123 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-51cf0eb9498ede5bd396324d-22'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4bcf2575aeedef3b6b3bc598',
#       'name': 'Mamma Mia',
#       'location': {'address': 'Karmelicka 14',
#        'lat': 50.06425417561614,
#        'lng': 19.93185634186023,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06425417561614,
#          'lng': 19.93185634186023}],
#        'postalCode': '31-133',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Karmelicka 14', '31-133 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4bcf2575aeedef3b6b3bc598-23'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4be59594cf200f47d760133c',
#       'name': 'Glonojad',
#       'location': {'address': 'pl. Matejki 2',
#        'lat': 50.066192,
#        'lng': 19.942359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.066192,
#          'lng': 19.942359}],
#        'postalCode': '31-157',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['pl. Matejki 2', '31-157 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1d3941735',
#         'name': 'Vegetarian / Vegan Restaurant',
#         'pluralName': 'Vegetarian / Vegan Restaurants',
#         'shortName': 'Vegetarian / Vegan',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4be59594cf200f47d760133c-24'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5831fe30fb549a1ff58ef339',
#       'name': 'Taste of India',
#       'location': {'address': 'Dietla 46',
#        'lat': 50.052622,
#        'lng': 19.94195,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.052622,
#          'lng': 19.94195}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Dietla 46', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d10f941735',
#         'name': 'Indian Restaurant',
#         'pluralName': 'Indian Restaurants',
#         'shortName': 'Indian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5831fe30fb549a1ff58ef339-25'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5bba2846610f04002c0de612',
#       'name': 'FloMaRo',
#       'location': {'address': 'Krupnicza 14',
#        'lat': 50.063435,
#        'lng': 19.930187,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.063435,
#          'lng': 19.930187}],
#        'postalCode': '31-123',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Krupnicza 14', '31-123 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d10c941735',
#         'name': 'French Restaurant',
#         'pluralName': 'French Restaurants',
#         'shortName': 'French',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5bba2846610f04002c0de612-26'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4c28c33b9eb195213e982959',
#       'name': 'Hard Rock Cafe Kraków',
#       'location': {'address': 'Main Market / Mariacki Square 9',
#        'crossStreet': 'Rynek Główny',
#        'lat': 50.0614424,
#        'lng': 19.9387328,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.0614424,
#          'lng': 19.9387328}],
#        'postalCode': '31-042',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Main Market / Mariacki Square 9 (Rynek Główny)',
#         '31-042 Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d14e941735',
#         'name': 'American Restaurant',
#         'pluralName': 'American Restaurants',
#         'shortName': 'American',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4c28c33b9eb195213e982959-27'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '57f63b44498e1ea0e270816d',
#       'name': 'stopbar',
#       'location': {'lat': 50.067384,
#        'lng': 19.944611,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.067384,
#          'lng': 19.944611}],
#        'cc': 'PL',
#        'country': 'Polska',
#        'formattedAddress': ['Polska']},
#       'categories': [{'id': '52e81612bcbc57f1066b7a04',
#         'name': 'Polish Restaurant',
#         'pluralName': 'Polish Restaurants',
#         'shortName': 'Polish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-57f63b44498e1ea0e270816d-28'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b6d7917f964a520c5762ce3',
#       'name': 'Nowa Prowincja',
#       'location': {'address': 'Bracka 3-5',
#        'lat': 50.06042809234986,
#        'lng': 19.93630811489708,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06042809234986,
#          'lng': 19.93630811489708}],
#        'postalCode': '31-005',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Bracka 3-5', '31-005 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4b6d7917f964a520c5762ce3-29'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '579f484f498e46e53a1df643',
#       'name': 'Karakter',
#       'location': {'address': 'Brzozowa 17',
#        'lat': 50.053226,
#        'lng': 19.94605,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.053226,
#          'lng': 19.94605}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Brzozowa 17', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-579f484f498e46e53a1df643-30'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '568926ae498eaff18379fd5c',
#       'name': 'Coffee Kiosk Krakow',
#       'location': {'address': 'Wielopole, 14',
#        'lat': 50.05857100116566,
#        'lng': 19.944802172794187,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05857100116566,
#          'lng': 19.944802172794187}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Wielopole, 14', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-568926ae498eaff18379fd5c-31'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4c81274874d7b60cfed273d8',
#       'name': 'Trattoria La Campana',
#       'location': {'address': 'Kanonicza 7',
#        'lat': 50.05702223722553,
#        'lng': 19.937251107278037,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05702223722553,
#          'lng': 19.937251107278037}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Kanonicza 7', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4c81274874d7b60cfed273d8-32'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '51f164a9498e2868eb5be966',
#       'name': 'Hummus Amamamusi',
#       'location': {'address': 'Beera Meisela 4',
#        'crossStreet': 'Dietla',
#        'lat': 50.050452,
#        'lng': 19.941507,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.050452,
#          'lng': 19.941507}],
#        'postalCode': '31-064',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Beera Meisela 4 (Dietla)',
#         '31-064 Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d115941735',
#         'name': 'Middle Eastern Restaurant',
#         'pluralName': 'Middle Eastern Restaurants',
#         'shortName': 'Middle Eastern',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-51f164a9498e2868eb5be966-33'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b9792bdf964a5206e0935e3',
#       'name': 'Dynia',
#       'location': {'address': 'Krupnicza 20',
#        'lat': 50.06336920517569,
#        'lng': 19.929198929609807,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06336920517569,
#          'lng': 19.929198929609807}],
#        'postalCode': '31-123',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Krupnicza 20', '31-123 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4b9792bdf964a5206e0935e3-34'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '56193c32498e5b08a853b2e6',
#       'name': 'Youmiko Sushi',
#       'location': {'address': 'Józefa 2',
#        'lat': 50.05031446908083,
#        'lng': 19.943129879955336,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05031446908083,
#          'lng': 19.943129879955336}],
#        'cc': 'PL',
#        'neighborhood': 'Kazimierz',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Józefa 2', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1d2941735',
#         'name': 'Sushi Restaurant',
#         'pluralName': 'Sushi Restaurants',
#         'shortName': 'Sushi',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-56193c32498e5b08a853b2e6-35'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5791b74c498eb395c3933d2b',
#       'name': 'Międzymiastowa',
#       'location': {'address': 'Dolnych Młynów 10 / 7a',
#        'lat': 50.06509180723766,
#        'lng': 19.92599479674023,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06509180723766,
#          'lng': 19.92599479674023}],
#        'postalCode': '31-124',
#        'cc': 'PL',
#        'neighborhood': 'Stare Miasto',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Dolnych Młynów 10 / 7a',
#         '31-124 Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d143941735',
#         'name': 'Breakfast Spot',
#         'pluralName': 'Breakfast Spots',
#         'shortName': 'Breakfast',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5791b74c498eb395c3933d2b-36'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '52f94e0e11d2f5c3816f93a6',
#       'name': 'Wesoła Cafe',
#       'location': {'address': 'Rakowicka 17',
#        'crossStreet': 'Topolowa',
#        'lat': 50.066698,
#        'lng': 19.952224,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.066698,
#          'lng': 19.952224}],
#        'postalCode': '31-511',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Rakowicka 17 (Topolowa)',
#         '31-511 Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '89836477'}},
#      'referralId': 'e-3-52f94e0e11d2f5c3816f93a6-37'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5639c271cd1086837a2fea42',
#       'name': 'Nolio',
#       'location': {'address': 'Krakowska 27',
#        'crossStreet': 'Skałeczna',
#        'lat': 50.049356389019216,
#        'lng': 19.942900604230978,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.049356389019216,
#          'lng': 19.942900604230978}],
#        'postalCode': '31-062',
#        'cc': 'PL',
#        'neighborhood': 'Kazimierz',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Krakowska 27 (Skałeczna)',
#         '31-062 Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1ca941735',
#         'name': 'Pizza Place',
#         'pluralName': 'Pizza Places',
#         'shortName': 'Pizza',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5639c271cd1086837a2fea42-38'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4cbb0e20f50e224bc352f7fb',
#       'name': 'Zazie',
#       'location': {'address': 'Józefa 34',
#        'crossStreet': 'Jakuba',
#        'lat': 50.05118726647844,
#        'lng': 19.947039488286308,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05118726647844,
#          'lng': 19.947039488286308}],
#        'postalCode': '31-056',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Józefa 34 (Jakuba)', '31-056 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d10c941735',
#         'name': 'French Restaurant',
#         'pluralName': 'French Restaurants',
#         'shortName': 'French',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4cbb0e20f50e224bc352f7fb-39'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4ce6b9d0f86537043eb2a4c4',
#       'name': 'Pizza Garden',
#       'location': {'address': 'Konopnickiej 11',
#        'lat': 50.05252971342023,
#        'lng': 19.929211245607018,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05252971342023,
#          'lng': 19.929211245607018}],
#        'postalCode': '31-511',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Konopnickiej 11', '31-511 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1ca941735',
#         'name': 'Pizza Place',
#         'pluralName': 'Pizza Places',
#         'shortName': 'Pizza',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4ce6b9d0f86537043eb2a4c4-40'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '545d21c4498e6198a0fd68e2',
#       'name': 'Pierożki u Vincenta',
#       'location': {'address': 'Bożego Ciała 12',
#        'lat': 50.051580864801316,
#        'lng': 19.943520580767235,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.051580864801316,
#          'lng': 19.943520580767235}],
#        'postalCode': '32-031',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Bożego Ciała 12', '32-031 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d108941735',
#         'name': 'Dumpling Restaurant',
#         'pluralName': 'Dumpling Restaurants',
#         'shortName': 'Dumplings',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-545d21c4498e6198a0fd68e2-41'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '58b8158851666a48d2be18c7',
#       'name': 'Ranny Ptaszek',
#       'location': {'address': 'Ul. Augustiańska 5',
#        'lat': 50.050337,
#        'lng': 19.941058,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.050337,
#          'lng': 19.941058}],
#        'postalCode': '31-064',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Ul. Augustiańska 5', '31-064 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d143941735',
#         'name': 'Breakfast Spot',
#         'pluralName': 'Breakfast Spots',
#         'shortName': 'Breakfast',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-58b8158851666a48d2be18c7-42'},
#     {'reasons': {'count': 0,
# ...
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-57153d38498eb2eba18750ba-84'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '580cc8cb38fab62600fc2ad1',
#       'name': 'Gąska',
#       'location': {'address': 'Limanowskiego 1',
#        'lat': 50.044964,
#        'lng': 19.950039,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.044964,
#          'lng': 19.950039}],
#        'postalCode': '30-551',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Limanowskiego 1', '30-551 Kraków', 'Polska']},
#       'categories': [{'id': '52e81612bcbc57f1066b7a04',
#         'name': 'Polish Restaurant',
#         'pluralName': 'Polish Restaurants',
#         'shortName': 'Polish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-580cc8cb38fab62600fc2ad1-85'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5a22c7b466fc65294b33a44f',
#       'name': 'Chez Nicolas',
#       'location': {'lat': 50.046148,
#        'lng': 19.955993,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.046148,
#          'lng': 19.955993}],
#        'postalCode': '30-548',
#        'cc': 'PL',
#        'neighborhood': 'Zabłocie',
#        'city': 'Kraków',
#        'state': 'Lesser Poland',
#        'country': 'Polska',
#        'formattedAddress': ['30-548 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d10c941735',
#         'name': 'French Restaurant',
#         'pluralName': 'French Restaurants',
#         'shortName': 'French',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5a22c7b466fc65294b33a44f-86'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '511d2cf8e4b05f03e29ab697',
#       'name': 'Zakładka',
#       'location': {'address': 'Józefińska 2',
#        'lat': 50.04577465491477,
#        'lng': 19.94828746986853,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.04577465491477,
#          'lng': 19.94828746986853}],
#        'postalCode': '30-529',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Józefińska 2', '30-529 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-511d2cf8e4b05f03e29ab697-87'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5597c00e498e0e9eb98716ac',
#       'name': 'Bistro Praska',
#       'location': {'lat': 50.046226836945316,
#        'lng': 19.91136079202096,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.046226836945316,
#          'lng': 19.91136079202096}],
#        'cc': 'PL',
#        'country': 'Polska',
#        'formattedAddress': ['Polska']},
#       'categories': [{'id': '52e81612bcbc57f1066b79f1',
#         'name': 'Bistro',
#         'pluralName': 'Bistros',
#         'shortName': 'Bistro',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5597c00e498e0e9eb98716ac-88'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4cdec7d23644a093f8354e9f',
#       'name': 'Marchewka z Groszkiem',
#       'location': {'address': 'Mostowa 2',
#        'lat': 50.04834534570277,
#        'lng': 19.945368595956648,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.04834534570277,
#          'lng': 19.945368595956648}],
#        'postalCode': '31-061',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Mostowa 2', '31-061 Kraków', 'Polska']},
#       'categories': [{'id': '52e81612bcbc57f1066b7a04',
#         'name': 'Polish Restaurant',
#         'pluralName': 'Polish Restaurants',
#         'shortName': 'Polish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4cdec7d23644a093f8354e9f-89'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '54aecbf5498e5e44af479042',
#       'name': 'Hindus',
#       'location': {'lat': 50.0472819262614,
#        'lng': 19.962357341587655,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.0472819262614,
#          'lng': 19.962357341587655}],
#        'cc': 'PL',
#        'country': 'Polska',
#        'formattedAddress': ['Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1cb941735',
#         'name': 'Food Truck',
#         'pluralName': 'Food Trucks',
#         'shortName': 'Food Truck',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-54aecbf5498e5e44af479042-90'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5410729e498e3840c179c58f',
#       'name': 'Metaforma',
#       'location': {'lat': 50.05468338866292,
#        'lng': 19.932948893096544,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05468338866292,
#          'lng': 19.932948893096544}],
#        'cc': 'PL',
#        'country': 'Polska',
#        'formattedAddress': ['Polska']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5410729e498e3840c179c58f-91'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4ba9050ef964a52059043ae3',
#       'name': 'Nova Resto Bar',
#       'location': {'address': 'Estery 18',
#        'lat': 50.051435981271034,
#        'lng': 19.94584481742575,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.051435981271034,
#          'lng': 19.94584481742575}],
#        'postalCode': '31-056',
#        'cc': 'PL',
#        'neighborhood': 'Kazimierz',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Estery 18', '31-056 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4ba9050ef964a52059043ae3-92'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5780ceab498ef49b1353286c',
#       'name': 'Veganic',
#       'location': {'address': 'Dolnych Młynów 10',
#        'lat': 50.06462349578763,
#        'lng': 19.927123676879855,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06462349578763,
#          'lng': 19.927123676879855}],
#        'postalCode': '31-127',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Dolnych Młynów 10', '31-127 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d1d3941735',
#         'name': 'Vegetarian / Vegan Restaurant',
#         'pluralName': 'Vegetarian / Vegan Restaurants',
#         'shortName': 'Vegetarian / Vegan',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-5780ceab498ef49b1353286c-93'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '58a32f11bbec666d4c3308a7',
#       'name': 'HariPrasad Samosa & Curry',
#       'location': {'address': 'Dietla 45-47/12',
#        'lat': 50.051973,
#        'lng': 19.942155,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.051973,
#          'lng': 19.942155}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Dietla 45-47/12', 'Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d10f941735',
#         'name': 'Indian Restaurant',
#         'pluralName': 'Indian Restaurants',
#         'shortName': 'Indian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-58a32f11bbec666d4c3308a7-94'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '513f1709e4b0300e086b746a',
#       'name': 'Bococa',
#       'location': {'address': 'Plac Inwalidów 7',
#        'lat': 50.06960175927319,
#        'lng': 19.925837920540403,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.06960175927319,
#          'lng': 19.925837920540403}],
#        'postalCode': '30-033',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Plac Inwalidów 7', '30-033 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d143941735',
#         'name': 'Breakfast Spot',
#         'pluralName': 'Breakfast Spots',
#         'shortName': 'Breakfast',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '80456110'}},
#      'referralId': 'e-3-513f1709e4b0300e086b746a-95'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '55055d54498e47cb20dd04a6',
#       'name': 'Castor Coffee & Lunch',
#       'location': {'address': 'Aleja Kijowska 40',
#        'lat': 50.07684653335951,
#        'lng': 19.917818871596687,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.07684653335951,
#          'lng': 19.917818871596687}],
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Aleja Kijowska 40', 'Kraków', 'Polska']},
#       'categories': [{'id': '52e81612bcbc57f1066b79f1',
#         'name': 'Bistro',
#         'pluralName': 'Bistros',
#         'shortName': 'Bistro',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-55055d54498e47cb20dd04a6-96'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '540b14dd498e413c5f7a0581',
#       'name': 'WOK Open Kitchen',
#       'location': {'address': 'Meiselsa 14',
#        'lat': 50.05102149711392,
#        'lng': 19.942859176647136,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.05102149711392,
#          'lng': 19.942859176647136}],
#        'cc': 'PL',
#        'country': 'Polska',
#        'formattedAddress': ['Meiselsa 14', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d142941735',
#         'name': 'Asian Restaurant',
#         'pluralName': 'Asian Restaurants',
#         'shortName': 'Asian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-540b14dd498e413c5f7a0581-97'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4f06f7a9e4b033211811bda2',
#       'name': 'Trattoria Cichy Kącik',
#       'location': {'address': 'ul. Daniela Chodowieckiego 1',
#        'lat': 50.062793915884626,
#        'lng': 19.90398914993576,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.062793915884626,
#          'lng': 19.90398914993576}],
#        'postalCode': '33-332',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['ul. Daniela Chodowieckiego 1',
#         '33-332 Kraków',
#         'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4f06f7a9e4b033211811bda2-98'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4d21fbcc29292d43cf6f5274',
#       'name': 'Bar Orientalny Phuong Dong',
#       'location': {'address': 'Lubelska 10',
#        'lat': 50.073889035443344,
#        'lng': 19.930838974895888,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 50.073889035443344,
#          'lng': 19.930838974895888}],
#        'postalCode': '30-003',
#        'cc': 'PL',
#        'city': 'Kraków',
#        'state': 'Województwo małopolskie',
#        'country': 'Polska',
#        'formattedAddress': ['Lubelska 10', '30-003 Kraków', 'Polska']},
#       'categories': [{'id': '4bf58dd8d48988d145941735',
#         'name': 'Chinese Restaurant',
#         'pluralName': 'Chinese Restaurants',
#         'shortName': 'Chinese',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-3-4d21fbcc29292d43cf6f5274-99'}]}]}

# %%
items = d["groups"][0]["items"]
print("number of items: %i" % len(items))
items[0]
# Out:
# number of items: 100
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '597cc55b6dcf041c42573b04',
#   'name': 'Pizzatopia',
#   'location': {'address': 'Szewska 22',
#    'lat': 50.062943238240265,
#    'lng': 19.933833687142826,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 50.062943238240265,
#      'lng': 19.933833687142826}],
#    'postalCode': '31-009',
#    'cc': 'PL',
#    'city': 'Kraków',
#    'state': 'Lesser Poland',
#    'country': 'Polska',
#    'formattedAddress': ['Szewska 22', '31-009 Kraków', 'Polska']},
#   'categories': [{'id': '4bf58dd8d48988d1ca941735',
#     'name': 'Pizza Place',
#     'pluralName': 'Pizza Places',
#     'shortName': 'Pizza',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-3-597cc55b6dcf041c42573b04-0'}

# %%
del_index = []
no_del_index = []
for i in range(0, len(items)):
    if 'address' in items[i]['venue']['location']:
        no_del_index.append(i)
    else:
        del_index.append(i)   
del_index.sort(reverse=True)

# %%
for i in del_index:
    del items[i]

# %%
df_raw = []
for item in items:
    venue = item["venue"]
    categories, uid, name, location = venue["categories"], venue["id"], venue["name"], venue["location"]
    assert len(categories) == 1
    shortname = categories[0]["shortName"]
    address = location["address"]
    if not "postalCode" in location:
        continue
    postalcode = location["postalCode"]
    lat = location["lat"]
    lng = location["lng"]
    datarow = (uid, name, shortname, address, postalcode, lat, lng)
    df_raw.append(datarow)
df = pd.DataFrame(df_raw, columns=["uid", "name", "food", "address", "postalcode", "lat", "lng"])
print("found %i restaurants" % len(df))
df.head()
# Out:
# found 59 restaurants
#                         uid                             name        food  \
# 0  597cc55b6dcf041c42573b04                       Pizzatopia       Pizza
# 1  53e678c5498e35f10c8bcbfa              Bianca Pasta & Wine     Italian
# 2  4e6f50cb483bd41a3db4dfa4                        MoaBurger     Burgers
# 3  53a1380f498e903f74523f65           Massolit Bakery & Cafe      Bakery
# 4  56377311498ea3a0befc336c  Bonerowska Gourmet Steak & Fish  Steakhouse
#
#            address postalcode        lat        lng
# 0       Szewska 22     31-009  50.062943  19.933834
# 1  Plac Mariacki 2     31-042  50.061899  19.939741
# 2     Mikołajska 3     31-027  50.061306  19.941310
# 3      Smoleńsk 17     31-108  50.058975  19.930351
# 4  Rynek Główny 42     31-013  50.062246  19.937987

# %%
print(df['food'].value_counts())
# Out:
# Café                  13
# Restaurant             5
# Italian                5
# Breakfast              4
# Bakery                 4
# Pizza                  4
# Polish                 3
# Vegetarian / Vegan     3
# French                 3
# Ramen                  2
# Steakhouse             2
# Burgers                2
# Middle Eastern         1
# Thai                   1
# Sandwiches             1
# Creperie               1
# Salad                  1
# Chinese                1
# Falafel                1
# American               1
# Dumplings              1
# Name: food, dtype: int64

# %%
krakow_center = d["geocode"]["center"]
krakow_center
# Out:
# {'lat': 50.06143, 'lng': 19.93658}

# %%
# create map of Helsinki using latitude and longitude values
map_krakow = folium.Map(location=[krakow_center["lat"], krakow_center["lng"]], zoom_start=14)

def add_markers(df):
    for (j, row) in df.iterrows():
        label = folium.Popup(row["name"], parse_html=True)
        folium.CircleMarker(
            [row["lat"], row["lng"]],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_krakow)

add_markers(df)
print(type(df[['lat','lng']]))
hm_data = df[['lat','lng']].values.tolist()
map_krakow.add_child(plugins.HeatMap(hm_data))

map_krakow
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# center: {'lat': 50.06143, 'lng': 19.93658}
lat = 50.05524
lng = 19.93358
map_krakow = folium.Map(location=[lat, lng], zoom_start=17)
add_markers(df)
folium.CircleMarker(
    [lat, lng],
    radius=15,
    popup="Our Cafe!",
    color='red',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_krakow)
map_krakow
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
